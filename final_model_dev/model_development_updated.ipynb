# %% [markdown]
# # 0.0 Preparation

# %%
pip install pandas --upgrade
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/xanvelaa/Library/Python/3.12/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/xanvelaa/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.20.3)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymc
# Out:
# Requirement already satisfied: pymc in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (5.21.1)
# Requirement already satisfied: arviz>=0.13.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (0.21.0)
# Requirement already satisfied: cachetools>=4.2.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (5.5.2)
# Requirement already satisfied: cloudpickle in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (3.0.0)
# Requirement already satisfied: numpy>=1.25.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (2.1.1)
# Requirement already satisfied: pandas>=0.24.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (2.2.3)
# Requirement already satisfied: pytensor<2.29,>=2.28.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (2.28.3)
# Requirement already satisfied: rich>=13.7.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (13.9.4)
# Requirement already satisfied: scipy>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (1.14.1)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pymc) (4.12.2)
# Requirement already satisfied: setuptools>=60.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (75.1.0)
# Requirement already satisfied: matplotlib>=3.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (3.9.2)
# Requirement already satisfied: packaging in /Users/xanvelaa/Library/Python/3.12/lib/python/site-packages (from arviz>=0.13.0->pymc) (24.1)
# Requirement already satisfied: xarray>=2022.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (2025.3.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (1.6.1)
# Requirement already satisfied: xarray-einstats>=0.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (0.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/xanvelaa/Library/Python/3.12/lib/python/site-packages (from pandas>=0.24.0->pymc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.24.0->pymc) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=0.24.0->pymc) (2024.1)
# Requirement already satisfied: filelock>=3.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytensor<2.29,>=2.28.2->pymc) (3.18.0)
# Requirement already satisfied: etuples in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytensor<2.29,>=2.28.2->pymc) (0.3.9)
# Requirement already satisfied: logical-unification in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytensor<2.29,>=2.28.2->pymc) (0.4.6)
# Requirement already satisfied: miniKanren in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytensor<2.29,>=2.28.2->pymc) (1.0.3)
# Requirement already satisfied: cons in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytensor<2.29,>=2.28.2->pymc) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from rich>=13.7.1->pymc) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/xanvelaa/Library/Python/3.12/lib/python/site-packages (from rich>=13.7.1->pymc) (2.18.0)
# Requirement already satisfied: h5py in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc) (3.13.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.5->arviz>=0.13.0->pymc) (3.1.4)
# Requirement already satisfied: six>=1.5 in /Users/xanvelaa/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pymc) (1.16.0)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from logical-unification->pytensor<2.29,>=2.28.2->pymc) (1.0.0)
# Requirement already satisfied: multipledispatch in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from logical-unification->pytensor<2.29,>=2.28.2->pymc) (1.0.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from openpyxl) (2.0.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 0.1 Imports

# %%
# Import Pandas 
import pandas as pd

## Set view to two decimal points only 
pd.set_option('float_format', '{:2f}' .format) 

# Import NumPy
import numpy as np

# Import from statsmodel
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA

# Import pyMC
import pymc as pm

# %% [markdown]
# # 1.0 Setting Roots and Functions

# %% [markdown]
# ## 1.1 Roots

# %%
user_root = "/Users/xanvelaa/Downloads/"

# %% [markdown]
# ## 1.1 Preprocessing

# %%
def preprocess_tourist_dataset (dataset):
    
    preprocessed_dataset = (
        dataset
        .assign(
            month = lambda x: x["date"].dt.month,
            year = lambda x: x["date"].dt.year
            )
            [["month", "year", "tourist_count"]]
            .pivot_table(
                values='tourist_count',  
                index='month',        
                columns='year',      
                )
                .reset_index()
    )

    return preprocessed_dataset

# %%
def preprocess_weather_dataset (dataset):
    
    preprocessed_dataset = (
        dataset
        [["date", "days_rained", "days_cloudy", "days_sunny"]]
        .assign(
            month = lambda x: x["date"].dt.month,
            year = lambda x: x["date"].dt.year
        )
        [["month", "year", "days_rained", "days_cloudy", "days_sunny"]]
        .sort_values(by=["month", "year"], ignore_index=True)

    )

    return preprocessed_dataset

# %% [markdown]
# ## 1.2 Modeling

# %%
def arima_forecast_25 (dataset):
    # Initialize dictionary to store forecasts
    forecasts = {}

    # Loop through each month and fit an ARIMA model
    for i, month in enumerate(dataset["month"]):
        # Get the time series for the current month (2022, 2023, 2024 values)
        ts = dataset.iloc[i, 1:].values  

        # Fit ARIMA model (p, d, q can be tuned)
        model = ARIMA(ts, order=(1, 1, 1))  
        model_fit = model.fit()
        
        # Forecast 1 step ahead (2025 value)
        forecast = model_fit.forecast(steps=1)[0]
        
        # Store the forecasted value
        forecasts[month] = forecast

    # Convert forecasts into a DataFrame
    forecast_df = (
        pd.DataFrame(

            list(forecasts.items()), 
            columns=["month", "Tourists"]
            )
            .assign(tourists = lambda x: x["Tourists"].astype(int))
            .assign(year = 2025)
            [["month", "year", "tourists"]]
            )

    return forecast_df

# %%
def dirichlet_multinomial_25 (dataset): 

    # Store predictions
    predictions = []

    # Get unique months in the dataset
    months = dataset["month"].unique()

    # Bayesian model loop for each month
    for month in months:
        # Filter data for the current month
        filtered_dataset = dataset.query(f"month == {month}")
        days_in_this_month = filtered_dataset.iloc[0][["days_rained", "days_cloudy", "days_sunny"]].sum()

    
        # Get observed counts and years
        observed_counts = filtered_dataset[["days_rained", "days_cloudy", "days_sunny"]].values
        years = filtered_dataset["year"].values
        k = observed_counts.shape[1]  # Number of weather categories

        # Define coordinates for PyMC
        coords = {"year": years, "weather": ["rainy", "cloudy", "sunny"]}

        with pm.Model(coords=coords) as model_dm:
            # Dirichlet prior for weather proportions
            frac = pm.Dirichlet("frac", a=np.ones(k), dims="weather")

            # Lognormal prior for concentration parameter
            conc = pm.Lognormal("conc", mu=1, sigma=1)
            
            # Dirichlet-Multinomial probabilities per year
            p = pm.Dirichlet("p", a=frac * conc, dims=("year", "weather"))
            
            # Multinomial likelihood
            counts = pm.Multinomial(
                "counts", n=days_in_this_month, p=p, observed=observed_counts, dims=("year", "weather")
            )

            # Sample from posterior
            trace = pm.sample(1000, tune=500, chains=2, return_inferencedata=True, cores=1)

        # Predict for 2025
        with model_dm:
            future_posterior = pm.sample_posterior_predictive(trace, var_names=["p"])

        # Extract predicted probabilities for 2025
        pred_p = future_posterior.posterior_predictive["p"].mean(dim=["chain", "draw"]).sel(year=2024)

        # Convert probabilities to predicted counts for a 31-day month
        pred_counts = (pred_p * days_in_this_month).round().astype(int)

        # Store results
        predictions.append({
            "month": month,
            "year": 2025,
            "days_rained": pred_counts.sel(weather="rainy").values.item(),
            "days_cloudy": pred_counts.sel(weather="cloudy").values.item(),
            "days_sunny": pred_counts.sel(weather="sunny").values.item()
        })

    # Turn predictions into a dataframe 
    weather_predictions = pd.DataFrame(predictions)
    return weather_predictions

# %% [markdown]
# ## 1.3 Merging

# %%
def merge_data_for_llm (tourist_df, weather_df, loc):
    llm_dataset = (
        pd
        .merge(
            weather_df,
            tourist_df,
            on = ["year", "month"],
            how = "outer")
        .query("year == 2025")
        .assign(location = loc)

    )

    return llm_dataset

# %% [markdown]
# # 2.0 Preprocessing + Modeling Datasets

# %% [markdown]
# ## 2.1 Boracay

# %% [markdown]
# ### 2.1.1 Tourists

# %%
# Read Boracay tourist dataset
boracay_df = pd.read_excel((user_root + "Boracay_Weather_Tourist.xlsx"), sheet_name = "tourist")

# Preprocess Boracay tourist dataset
boracay_tourist_preprocessed = preprocess_tourist_dataset(boracay_df)

# Forecast number of tourists for 2025 
boracay_tourists_forecasted = arima_forecast_25(boracay_tourist_preprocessed)
boracay_tourists_forecasted

# %%
boracay_tourists_forecasted
# Out:
#     month  year  tourists
# 0       1  2025    146323
# 1       2  2025    161727
# 2       3  2025    192503
# 3       4  2025    193003
# 4       5  2025    206013
# 5       6  2025    190545
# 6       7  2025    167744
# 7       8  2025    124315
# 8       9  2025    156059
# 9      10  2025    175847
# 10     11  2025    173795
# 11     12  2025    153339

# %% [markdown]
# ### 2.1.2 Weather

# %%
# Read Boracay weather dataset
weather_df = pd.read_excel((user_root + "Boracay_Weather_Tourist.xlsx"), sheet_name = "weather")

# Preprocess Boracay weather dataset
boracay_weather_preprocessed = preprocess_weather_dataset(weather_df)

# Forecast weather for 2025
boracay_weather_forecasted = dirichlet_multinomial_25(boracay_weather_preprocessed)

# %%
boracay_weather_forecasted
# Out:
#     month  year  days_rained  days_cloudy  days_sunny
# 0       1  2025           17            8           6
# 1       2  2025           13            9           6
# 2       3  2025            7           14          10
# 3       4  2025            9           12          10
# 4       5  2025           11           11           9
# 5       6  2025           18            8           4
# 6       7  2025           20            8           3
# 7       8  2025           18            9           4
# 8       9  2025           19            8           3
# 9      10  2025           18           10           3
# 10     11  2025           15           11           5
# 11     12  2025           15           11           5

# %% [markdown]
# ### 2.1.3 Merge DFs

# %%
boracay_predictions_25 = merge_data_for_llm(
    boracay_tourists_forecasted,
    boracay_weather_forecasted,
    "Boracay")

boracay_predictions_25
# Out:
#     month  year  days_rained  days_cloudy  days_sunny  tourists location
# 0       1  2025           17            8           6    146323  Boracay
# 1       2  2025           13            9           6    161727  Boracay
# 2       3  2025            7           14          10    192503  Boracay
# 3       4  2025            9           12          10    193003  Boracay
# 4       5  2025           11           11           9    206013  Boracay
# 5       6  2025           18            8           4    190545  Boracay
# 6       7  2025           20            8           3    167744  Boracay
# 7       8  2025           18            9           4    124315  Boracay
# 8       9  2025           19            8           3    156059  Boracay
# 9      10  2025           18           10           3    175847  Boracay
# 10     11  2025           15           11           5    173795  Boracay
# 11     12  2025           15           11           5    153339  Boracay

# %% [markdown]
# ## 2.2 Bohol

# %% [markdown]
# ### 2.2.1 Tourists

# %%
# Read Bohol tourist dataset
bohol_df = pd.read_excel((user_root + "Bohol_Weather_Tourist.xlsx"), sheet_name = "tourist")

# Preprocess Bohol tourist dataset
bohol_tourist_preprocessed = preprocess_tourist_dataset(bohol_df)

# Forecast number of tourists for 2025 
bohol_tourists_forecasted = arima_forecast_25(bohol_tourist_preprocessed)

# %%
bohol_tourists_forecasted
# Out:
#     month  year  tourists
# 0       1  2025    129658
# 1       2  2025    140046
# 2       3  2025    115024
# 3       4  2025    111723
# 4       5  2025    137137
# 5       6  2025    126981
# 6       7  2025    144690
# 7       8  2025    140216
# 8       9  2025    120277
# 9      10  2025    127919
# 10     11  2025    133685
# 11     12  2025    167263

# %% [markdown]
# ### 2.2.2 Weather

# %%
# Read Bohol weather dataset
bohol_weather_df = pd.read_excel((user_root + "Bohol_Weather_Tourist.xlsx"), sheet_name = "weather")

# Preprocess Bohol weather dataset
bohol_weather_preprocessed = preprocess_weather_dataset(bohol_weather_df)

# Forecast weather for 2025
bohol_weather_forecasted = dirichlet_multinomial_25(bohol_weather_preprocessed)

# %%
bohol_weather_forecasted
# Out:
#     month  year  days_rained  days_cloudy  days_sunny
# 0       1  2025           21            8           2
# 1       2  2025           16           10           3
# 2       3  2025           20            8           3
# 3       4  2025           17            9           3
# 4       5  2025           15           12           4
# 5       6  2025           15           12           3
# 6       7  2025           14           14           4
# 7       8  2025           11           16           4
# 8       9  2025           12           14           4
# 9      10  2025           19           10           2
# 10     11  2025           21            7           2
# 11     12  2025           23            6           2

# %% [markdown]
# ### 2.2.3 Merge DFs

# %%
bohol_predictions_25 = merge_data_for_llm(
    bohol_tourists_forecasted,
    bohol_weather_forecasted,
    "Bohol")

bohol_predictions_25
# Out:
#     month  year  days_rained  days_cloudy  days_sunny  tourists location
# 0       1  2025           21            8           2    129658    Bohol
# 1       2  2025           16           10           3    140046    Bohol
# 2       3  2025           20            8           3    115024    Bohol
# 3       4  2025           17            9           3    111723    Bohol
# 4       5  2025           15           12           4    137137    Bohol
# 5       6  2025           15           12           3    126981    Bohol
# 6       7  2025           14           14           4    144690    Bohol
# 7       8  2025           11           16           4    140216    Bohol
# 8       9  2025           12           14           4    120277    Bohol
# 9      10  2025           19           10           2    127919    Bohol
# 10     11  2025           21            7           2    133685    Bohol
# 11     12  2025           23            6           2    167263    Bohol

# %% [markdown]
# ## 2.3 Cebu

# %% [markdown]
# ### 2.3.1 Tourists

# %%
# Read Cebu tourist dataset
cebu_df = pd.read_excel((user_root + "Cebu_Weather_Tourist.xlsx"), sheet_name = "tourist")

# Preprocess Bohol tourist dataset
cebu_tourist_preprocessed = preprocess_tourist_dataset(cebu_df)

# Forecast number of tourists for 2025 
cebu_tourists_forecasted = arima_forecast_25(cebu_tourist_preprocessed)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
cebu_tourists_forecasted
# Out:
#     month  year  tourists
# 0       1  2025    490812
# 1       2  2025    394330
# 2       3  2025    335634
# 3       4  2025    302281
# 4       5  2025    337122
# 5       6  2025    330585
# 6       7  2025    378859
# 7       8  2025    362876
# 8       9  2025    328300
# 9      10  2025    362762
# 10     11  2025    403929
# 11     12  2025    520444

# %% [markdown]
# ### 2.3.2 Weather

# %%
# Read Cebu weather dataset
cebu_weather_df = pd.read_excel((user_root + "Cebu_Weather_Tourist.xlsx"), sheet_name = "weather")

# Preprocess Bohol weather dataset
cebu_weather_preprocessed = preprocess_weather_dataset(cebu_weather_df)

# Forecast weather for 2025
cebu_weather_forecasted = dirichlet_multinomial_25(cebu_weather_preprocessed)

# %%
cebu_weather_forecasted
# Out:
#     month  year  days_rained  days_cloudy  days_sunny
# 0       1  2025           17            9           5
# 1       2  2025           13           10           5
# 2       3  2025           11           11           9
# 3       4  2025           13           10           6
# 4       5  2025           14           11           6
# 5       6  2025           16           11           3
# 6       7  2025           20            9           2
# 7       8  2025           18            9           3
# 8       9  2025           19            9           2
# 9      10  2025           22            7           2
# 10     11  2025           18            9           4
# 11     12  2025           18            9           4

# %% [markdown]
# ### 2.2.3 Merge DFs

# %%
cebu_predictions_25 = merge_data_for_llm(
    cebu_tourists_forecasted,
    cebu_weather_forecasted,
    "Cebu")

cebu_predictions_25
# Out:
#     month  year  days_rained  days_cloudy  days_sunny  tourists location
# 0       1  2025           17            9           5    490812     Cebu
# 1       2  2025           13           10           5    394330     Cebu
# 2       3  2025           11           11           9    335634     Cebu
# 3       4  2025           13           10           6    302281     Cebu
# 4       5  2025           14           11           6    337122     Cebu
# 5       6  2025           16           11           3    330585     Cebu
# 6       7  2025           20            9           2    378859     Cebu
# 7       8  2025           18            9           3    362876     Cebu
# 8       9  2025           19            9           2    328300     Cebu
# 9      10  2025           22            7           2    362762     Cebu
# 10     11  2025           18            9           4    403929     Cebu
# 11     12  2025           18            9           4    520444     Cebu

# %% [markdown]
# # 3.0 Append Datasets for LLM Fine Tuning

# %%
datasets = [
    boracay_predictions_25,
    bohol_predictions_25,
    cebu_predictions_25
]

column_list = (
    boracay_predictions_25
    .columns[1:5]
    .insert(0, "location")
)

train_data_updated = (
    pd.concat(
        datasets,
        axis = 0,
        ignore_index = True
    )
    [column_list]

)

# %%
train_data_updated.to_csv("train_data_updated.csv")

# %%
train_data.to_csv("train_data.csv")
